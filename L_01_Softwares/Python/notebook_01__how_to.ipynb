# %% [markdown]
# ### Definições preliminares

# %%
import cv2 # OpenCV
import numpy as np # biblioteca para trablahar com arrays de forme eficiente
import matplotlib.pyplot as plt # biblioteca para plotar gráficos

# %% [markdown]
# ## Carregar imagem

# %%
img = cv2.imread('../figs/lena_color_256.tif')

# %%
img
# Out:
# array([[[125, 137, 226],
#         [130, 136, 223],
#         [118, 133, 226],
#         ...,
#         [127, 145, 230],
#         [122, 148, 232],
#         [100, 114, 210]],
#
#        [[125, 137, 226],
#         [130, 136, 223],
#         [118, 133, 226],
#         ...,
#         [127, 145, 230],
#         [122, 148, 232],
#         [100, 114, 210]],
#
#        [[124, 138, 226],
#         [121, 133, 223],
#         [117, 134, 226],
#         ...,
#         [118, 133, 222],
#         [108, 125, 217],
#         [ 90,  87, 182]],
#
#        ...,
#
#        [[ 61,  28,  90],
#         [ 61,  28,  91],
#         [ 63,  29,  97],
#         ...,
#         [ 71,  53, 140],
#         [ 73,  62, 158],
#         [ 74,  59, 161]],
#
#        [[ 60,  20,  85],
#         [ 59,  25,  91],
#         [ 62,  26,  94],
#         ...,
#         [ 82,  64, 153],
#         [ 81,  69, 172],
#         [ 78,  65, 170]],
#
#        [[ 57,  22,  82],
#         [ 62,  30,  94],
#         [ 61,  25,  95],
#         ...,
#         [ 84,  71, 167],
#         [ 78,  68, 178],
#         [ 81,  72, 183]]], dtype=uint8)

# %%
img[:,:,1]
# Out:
# array([[137, 136, 133, ..., 145, 148, 114],
#        [137, 136, 133, ..., 145, 148, 114],
#        [138, 133, 134, ..., 133, 125,  87],
#        ...,
#        [ 28,  28,  29, ...,  53,  62,  59],
#        [ 20,  25,  26, ...,  64,  69,  65],
#        [ 22,  30,  25, ...,  71,  68,  72]], dtype=uint8)

# %%
img.shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Exibir a imagem

# %% [markdown]
# ### Pela OpenCV

# %%
cv2.imshow('Image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Pela Matplotlib

# %%
plt.imshow(img, cmap=cm.RdYlGn)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fb952896a177> in <module>()
# ----> 1 plt.imshow(img, cmap=cm.RdYlGn)
#       2 plt.show()
#
# NameError: name 'cm' is not defined

# %%
img = cv2.imread('../figs/lena_color_256.tif', cv2.IMREAD_GRAYSCALE)
img
# Out:
# array([[162, 161, 159, ..., 168, 170, 141],
#        [162, 161, 159, ..., 168, 170, 141],
#        [163, 159, 160, ..., 158, 151, 116],
#        ...,
#        [ 50,  51,  53, ...,  81,  92,  91],
#        [ 44,  49,  50, ...,  93, 101,  98],
#        [ 44,  53,  50, ..., 101, 102, 106]], dtype=uint8)

# %%
img.shape
# Out:
# (256, 256)

# %%
plt.imshow(img)
plt.imshow(img, 'gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
